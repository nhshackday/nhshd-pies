# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('seaborn-white')

# %%
# Data to plot

# sector
# corporate role
# geographic location

labels = 'Hospital managers', 'Healthcare software developers', 'NHS Doctors', 'Other'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

labels = 'Hospital managers', 'Healthcare software developers', 'NHS Doctors', 'Other'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)

plt.rcParams.update({'font.size': 22})

f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, sharex=True, figsize=(18,4))

"""
health
software
hardware
government
academic
other
"""
labels = 'NHS', 'IT', 'Other', 'Gov'
sizes = [400, 300, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
ax1.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

"""
labels = 'Manager', 'Doctor', 'Other', 'Developer'
sizes = [280, 130, 180, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
ax2.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

labels = 'London', 'South east', 'North', 'Other'
sizes = [300, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
ax3.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax1.set_title('Sector')
ax2.set_title('Corporate role')
ax3.set_title('Geographic location')

f.savefig('attendee_profile.png')
